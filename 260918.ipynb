# %%
print("hello, world")
# Out:
# hello, world

# %%
#100분은 몇시간 몇분인지 출력해 보세요

# %%
time=100

print(100//60 + '시간' + 100%60 + '분')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 time=100
# ----> 3 print(100//60 + '시간' + 100%60 + '분')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(100//60 + '시간' + 100%60 + '분')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(100//60 + '시간' + 100%60 + '분')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print("100//60 + '시간' + 100%60 + '분'")
# Out:
# 100//60 + '시간' + 100%60 + '분'

# %%
print(100//60+'시간', 100%60+'분')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(100//60+'시간', 100%60+'분')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(100//60)
# Out:
# 1

# %%
print(100//60,'시간', 100%60,'분')
# Out:
# 1 시간 40 분

# %%
time=100

print(time//60, '시간', time%60,'분')
# Out:
# 1 시간 40 분

# %%
print('100분은', 100//60,'시간', 100%60,'분입니다.')
# Out:
# 100분은 1 시간 40 분입니다.

# %%
time=100

print(time//60, '시간', time%60,'분입니다.')
# Out:
# 1 시간 40 분입니다.

# %%
time=100
print(time,'분은', time//60,'시간', time%60,'분 입니다.')
# Out:
# 100 분은 1 시간 40 분 입니다.

# %%
time= int(input("시간을 입력하세요."))

print(time, "분은", time//60, "시간", time%60, "분 입니다.") 

print(f"{time}분은 {time//60}시간 {time%60}분 입니다.")
# Out:
# 시간을 입력하세요. 19237289
# 19237289 분은 320621 시간 29 분 입니다.
# 19237289분은 320621시간 29분 입니다.

# %%
a=10
#a= a+7
a+=7
a
# Out:
# 17

# %%
#2.1.3 변수 이름의 규칙 시험에 잘 나옮, 변수 이름(특색 있는 이름을 지어야함)

import keyword
print(keyword, kwlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 #2.1.3 변수 이름의 규칙 시험에 잘 나옮, 변수 이름(특색 있는 이름을 지어야함)
#       3 import keyword
# ----> 4 print(keyword, kwlist)
#
# NameError: name 'kwlist' is not defined

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#두 변수의 값 교환하기

# %%
a="소주"
b="맥주"
temp= b
b = a
a = temp

print(a, b)
# Out:
# 맥주 소주

# %%
name= input("이름을 입력하세요: ")
age= input("나이를 입력하세요: ")

print(name, age)
# Out:
# 이름을 입력하세요:  박찬웅
# 나이를 입력하세요:  24
# 박찬웅 24

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
name= input("이름을 입력하세요: ")
age= int(input("나이를 입력하세요: "))
print(name, age)
# Out:
# 이름을 입력하세요:  홍길동
# 나이를 입력하세요:  20
# 홍길동 20

# %%
age=age+1

# %%
age
# Out:
# 21

# %%
if True:
    print("참")
# Out:
# 참

# %%
if False:
# Out:
#   Cell In[63], line 1
#     if False:
#              ^
# SyntaxError: incomplete input

# %%
if True:
    print("참")
else:
    print("거짓")
# Out:
# 참

# %%
#숫자를 입력 받아서 그 숫자가 짝수인지 홀수인지 출력하는 프로그램을 작성하시오.

# %%
num= int(input("숫자를 입력하세요"))
if num%2==0 :
 print("짝수입니다.")
else:
 print("홀수입니다.")
# Out:
# 숫자를 입력하세요 100
# 짝수입니다.
